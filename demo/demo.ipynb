# %% [markdown]
# ## Setup

# %%
from blackjack_simulator.components.chart import Chart
from blackjack_simulator.simulation.simulator import Simulator

# %%
import os
os.chdir(os.path.split(os.getcwd())[0])

chart = Chart.from_excel('data/strategy_charts.xlsx')

# %% [markdown]
# Blackjack strategy chart shows what action a player should taken given the scenario of the hands dealt. The dataframes index represents the players starting cards, and the colummns represent the dealer upcard value. Note the player hands (index) includes hand totals (integers), soft totals (numbers with s prefix), and pairs.
#
# The simulation will perform the action shown in the table.

# %%
chart.df
# Out:
#                    2              3              4              5  \
# 5         Action.HIT     Action.HIT     Action.HIT     Action.HIT
# 6         Action.HIT     Action.HIT     Action.HIT     Action.HIT
# 7         Action.HIT     Action.HIT     Action.HIT     Action.HIT
# 8         Action.HIT     Action.HIT     Action.HIT     Action.HIT
# 9         Action.HIT  Action.DOUBLE  Action.DOUBLE  Action.DOUBLE
# 10     Action.DOUBLE  Action.DOUBLE  Action.DOUBLE  Action.DOUBLE
# 11     Action.DOUBLE  Action.DOUBLE  Action.DOUBLE  Action.DOUBLE
# 12        Action.HIT     Action.HIT   Action.STAND   Action.STAND
# 13      Action.STAND   Action.STAND   Action.STAND   Action.STAND
# 14      Action.STAND   Action.STAND   Action.STAND   Action.STAND
# 15      Action.STAND   Action.STAND   Action.STAND   Action.STAND
# 16      Action.STAND   Action.STAND   Action.STAND   Action.STAND
# 17      Action.STAND   Action.STAND   Action.STAND   Action.STAND
# 18      Action.STAND   Action.STAND   Action.STAND   Action.STAND
# 19      Action.STAND   Action.STAND   Action.STAND   Action.STAND
# 20      Action.STAND   Action.STAND   Action.STAND   Action.STAND
# s13       Action.HIT     Action.HIT     Action.HIT  Action.DOUBLE
# s14       Action.HIT     Action.HIT     Action.HIT  Action.DOUBLE
# s15       Action.HIT     Action.HIT  Action.DOUBLE  Action.DOUBLE
# s16       Action.HIT     Action.HIT  Action.DOUBLE  Action.DOUBLE
# s17       Action.HIT  Action.DOUBLE  Action.DOUBLE  Action.DOUBLE
# s18     Action.STAND  Action.DOUBLE  Action.DOUBLE  Action.DOUBLE
# s19     Action.STAND   Action.STAND   Action.STAND   Action.STAND
# s20     Action.STAND   Action.STAND   Action.STAND   Action.STAND
# 2,2     Action.SPLIT   Action.SPLIT   Action.SPLIT   Action.SPLIT
# 3,3     Action.SPLIT   Action.SPLIT   Action.SPLIT   Action.SPLIT
# 4,4       Action.HIT     Action.HIT     Action.HIT   Action.SPLIT
# 5,5    Action.DOUBLE  Action.DOUBLE  Action.DOUBLE  Action.DOUBLE
# 6,6     Action.SPLIT   Action.SPLIT   Action.SPLIT   Action.SPLIT
# 7,7     Action.SPLIT   Action.SPLIT   Action.SPLIT   Action.SPLIT
# 8,8     Action.SPLIT   Action.SPLIT   Action.SPLIT   Action.SPLIT
# 9,9     Action.SPLIT   Action.SPLIT   Action.SPLIT   Action.SPLIT
# 10,10   Action.STAND   Action.STAND   Action.STAND   Action.STAND
# A,A     Action.SPLIT   Action.SPLIT   Action.SPLIT   Action.SPLIT
#
#                    6              7              8                 9  \
# 5         Action.HIT     Action.HIT     Action.HIT        Action.HIT
# 6         Action.HIT     Action.HIT     Action.HIT        Action.HIT
# 7         Action.HIT     Action.HIT     Action.HIT        Action.HIT
# 8         Action.HIT     Action.HIT     Action.HIT        Action.HIT
# 9      Action.DOUBLE     Action.HIT     Action.HIT        Action.HIT
# 10     Action.DOUBLE  Action.DOUBLE  Action.DOUBLE     Action.DOUBLE
# 11     Action.DOUBLE  Action.DOUBLE  Action.DOUBLE     Action.DOUBLE
# 12      Action.STAND     Action.HIT     Action.HIT        Action.HIT
# 13      Action.STAND     Action.HIT     Action.HIT        Action.HIT
# 14      Action.STAND     Action.HIT     Action.HIT        Action.HIT
# 15      Action.STAND     Action.HIT     Action.HIT        Action.HIT
# 16      Action.STAND     Action.HIT     Action.HIT  Action.SURRENDER
# 17      Action.STAND   Action.STAND   Action.STAND      Action.STAND
# 18      Action.STAND   Action.STAND   Action.STAND      Action.STAND
# 19      Action.STAND   Action.STAND   Action.STAND      Action.STAND
# 20      Action.STAND   Action.STAND   Action.STAND      Action.STAND
# s13    Action.DOUBLE     Action.HIT     Action.HIT        Action.HIT
# s14    Action.DOUBLE     Action.HIT     Action.HIT        Action.HIT
# s15    Action.DOUBLE     Action.HIT     Action.HIT        Action.HIT
# s16    Action.DOUBLE     Action.HIT     Action.HIT        Action.HIT
# s17    Action.DOUBLE     Action.HIT     Action.HIT        Action.HIT
# s18    Action.DOUBLE   Action.STAND   Action.STAND        Action.HIT
# s19     Action.STAND   Action.STAND   Action.STAND      Action.STAND
# s20     Action.STAND   Action.STAND   Action.STAND      Action.STAND
# 2,2     Action.SPLIT   Action.SPLIT     Action.HIT        Action.HIT
# 3,3     Action.SPLIT   Action.SPLIT     Action.HIT        Action.HIT
# 4,4     Action.SPLIT     Action.HIT     Action.HIT        Action.HIT
# 5,5    Action.DOUBLE  Action.DOUBLE  Action.DOUBLE     Action.DOUBLE
# 6,6     Action.SPLIT     Action.HIT     Action.HIT        Action.HIT
# 7,7     Action.SPLIT   Action.SPLIT     Action.HIT        Action.HIT
# 8,8     Action.SPLIT   Action.SPLIT   Action.SPLIT      Action.SPLIT
# 9,9     Action.SPLIT   Action.STAND   Action.SPLIT      Action.SPLIT
# 10,10   Action.STAND   Action.STAND   Action.STAND      Action.STAND
# A,A     Action.SPLIT   Action.SPLIT   Action.SPLIT      Action.SPLIT
#
#                      10                 A
# 5            Action.HIT        Action.HIT
# 6            Action.HIT        Action.HIT
# 7            Action.HIT        Action.HIT
# 8            Action.HIT        Action.HIT
# 9            Action.HIT        Action.HIT
# 10           Action.HIT        Action.HIT
# 11        Action.DOUBLE        Action.HIT
# 12           Action.HIT        Action.HIT
# 13           Action.HIT        Action.HIT
# 14           Action.HIT        Action.HIT
# 15     Action.SURRENDER        Action.HIT
# 16     Action.SURRENDER  Action.SURRENDER
# 17         Action.STAND      Action.STAND
# 18         Action.STAND      Action.STAND
# 19         Action.STAND      Action.STAND
# 20         Action.STAND      Action.STAND
# s13          Action.HIT        Action.HIT
# s14          Action.HIT        Action.HIT
# s15          Action.HIT        Action.HIT
# s16          Action.HIT        Action.HIT
# s17          Action.HIT        Action.HIT
# s18          Action.HIT        Action.HIT
# s19        Action.STAND      Action.STAND
# s20        Action.STAND      Action.STAND
# 2,2          Action.HIT        Action.HIT
# 3,3          Action.HIT        Action.HIT
# 4,4          Action.HIT        Action.HIT
# 5,5          Action.HIT        Action.HIT
# 6,6          Action.HIT        Action.HIT
# 7,7          Action.HIT        Action.HIT
# 8,8        Action.SPLIT      Action.SPLIT
# 9,9        Action.STAND      Action.STAND
# 10,10      Action.STAND      Action.STAND
# A,A        Action.SPLIT      Action.SPLIT

# %% [markdown]
# ## Create and Run Simulation

# %%
simulator = Simulator(chart)

# %% [markdown]
# Show defaults for simulation. All adjustable on Simulator init.
#
# No insurance option. Insurance is for suckers.

# %%
print(f'{"Blackjack Payout:":<22} {simulator.blackjack_payout}')
print(f'{"Surrender Payout:":<22} {simulator.surrender_payout}')
print(f'{"Number of Decks:":<22} {simulator.n_decks}')
print(f'{"Dealer Hits Soft 17?:":<22} {simulator.dealer_hit_soft_17}')
print(f'{"Max Splits:":<22} {simulator.max_splits}')
# Out:
# Blackjack Payout:      1.5
# Surrender Payout:      0.5
# Number of Decks:       6
# Dealer Hits Soft 17?:  True
# Max Splits:            4

# %% [markdown]
# The last input to simulator is the Counter which is a basic map of high, medium, low cards that can be used to determine count of deck. A user can make a custom counter (not shown) and specify in Simulator init. By default, the counter will be as shown below.

# %%
print(f'Low card values: {[c.value for c in simulator.counter.plus_list]}')
print(f'Med cards values: {[c.value for c in simulator.counter.neutral_list]}')
print(f'High cards values: {[c.value for c in simulator.counter.minus_list]}')
# Out:
# Low card values: [2, 3, 4, 5, 6]
# Med cards values: [7, 8, 9]
# High cards values: [10, 'J', 'Q', 'K', 'A']

# %% [markdown]
# Run 3000 hands
#
# Just like in 'traditional' blackjack, there is a shoe and a cut card. When cut card is reach, deck is reset (important for deck count).
#
# TBD if i will include one of janky versions where they use a machine to shuffle each time.. wonder if it would slow things down

# %%
simulator.run(3000)

# %% [markdown]
# ## Output
#
# - Overall / Summary ouput
# - Chart Tables
# - Record Table

# %% [markdown]
# Summary is straightforward

# %%
simulator.output_summary()
# Out:
# ('Wins:1762, Pushes:420, Losses:2371',
#  'Buyin:4959, Payout:4930.5, Net:-28.5',
#  'Net_Units:-28.5, Obs:4553.0, EV:-0.0063')

# %% [markdown]
# Chart views show the situation and a breakdown of the hand results. Acceptable type inputs include `['profit', 'win', 'ev']`

# %%
simulator.output_chart('profit')
# Out:
#    player_hand                            2                             3  \
# 0            5     Buyin:1, Payout:2, Net:1      Buyin:2, Payout:2, Net:0
# 7       Buyin:106, Payout:54, Net:-52      Buyin:26, Payout:8, Net:-18
# 8       Buyin:110, Payout:62, Net:-48     Buyin:32, Payout:13, Net:-19
# 9   Buyin:114, Payout:47.5, Net:-66.5      Buyin:25, Payout:9, Net:-16
# 10  Buyin:107, Payout:51.5, Net:-55.5      Buyin:36, Payout:9, Net:-27
# 11  Buyin:105, Payout:47.0, Net:-58.0  Buyin:29, Payout:8.5, Net:-20.5
# 12       Buyin:93, Payout:45, Net:-48     Buyin:27, Payout:14, Net:-13
# 13      Buyin:109, Payout:69, Net:-40      Buyin:24, Payout:15, Net:-9
# 14        Buyin:95, Payout:101, Net:6       Buyin:18, Payout:18, Net:0
# 15      Buyin:113, Payout:172, Net:59       Buyin:24, Payout:27, Net:3
# 16         Buyin:18, Payout:19, Net:1         Buyin:4, Payout:4, Net:0
# 17           Buyin:4, Payout:4, Net:0         Buyin:4, Payout:4, Net:0
# 18          Buyin:7, Payout:4, Net:-3        Buyin:2, Payout:0, Net:-2
# 19         Buyin:10, Payout:2, Net:-8        Buyin:2, Payout:0, Net:-2
# 20          Buyin:4, Payout:3, Net:-1         Buyin:1, Payout:2, Net:1
# 21          Buyin:3, Payout:0, Net:-3        Buyin:4, Payout:2, Net:-2
# 22          Buyin:4, Payout:2, Net:-2        Buyin:2, Payout:0, Net:-2
# 23     Buyin:13, Payout:14.5, Net:1.5        Buyin:1, Payout:0, Net:-1
# 24          Buyin:3, Payout:0, Net:-3        Buyin:3, Payout:2, Net:-1
# 25         Buyin:15, Payout:19, Net:4         Buyin:2, Payout:2, Net:0
# 26         Buyin:17, Payout:17, Net:0        Buyin:4, Payout:2, Net:-2
# 27         Buyin:15, Payout:6, Net:-9        Buyin:5, Payout:2, Net:-3
# 28         Buyin:13, Payout:6, Net:-7        Buyin:4, Payout:2, Net:-2
# 29        Buyin:18, Payout:10, Net:-8        Buyin:2, Payout:1, Net:-1
# 30        Buyin:21, Payout:17, Net:-4        Buyin:8, Payout:4, Net:-4
# 31        Buyin:22, Payout:20, Net:-2         Buyin:3, Payout:4, Net:1
# 32        Buyin:29, Payout:25, Net:-4        Buyin:1, Payout:0, Net:-1
# 33         Buyin:20, Payout:26, Net:6         Buyin:5, Payout:6, Net:1

# %% [markdown]
# Last output type is a table of the hands, situations, actions, and output (result => {win:1, push:0, lose:-1})

# %%
records_table = simulator.records_to_df()

# %%
records_table.head()
# Out:
#   hand_id player_hand_lookup dealer_upcard_value  count  chart  bet_units  \
# 0  000000              10,10                   4      0      1          1
# 1  000001                 14                   5      0      1          1
# 2  000002                 13                   7     -1      1          1
# 3  000002                 15                   7     -1      1          1
# 4  000003                 16                  10     -1      1          1
#
#              action hit_card  final_payout  result
# 0      Action.STAND     None           2.0       1
# 1      Action.STAND     None           2.0       1
# 2        Action.HIT       2♠           0.0      -1
# 3        Action.HIT      10♣           0.0      -1
# 4  Action.SURRENDER     None           0.5      -1
